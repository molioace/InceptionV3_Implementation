# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, BatchNormalization, Input, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import ReLU
from tensorflow.keras.models import Model

# %%
def inception_naive_module(x, f1, f2, f3):
    c1 = Conv2D(f1, (1, 1), padding='same', activation='relu')(x)
    c2 = Conv2D(f2, (3, 3), padding='same', activation='relu')(x)
    c3 = Conv2D(f3, (5, 5), padding='same', activation='relu')(x)
    pool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    out = concatenate(c1, c2, c3, pool)
    return out

# %%
def conv2d_bn(x, filters, filter_size, padding='same', strides=(1, 1)):
    x = Conv2D(filters, filter_size, padding=padding, strides=strides)(x)
    x = BatchNormalization(axis=3, scale=False)(x)
    x = ReLU()(x)
    return x

# %%
def inc_block_a(x):
    first_branch = conv2d_bn(x, 64, (1, 1),  padding='same', strides=(1, 1))

    second_branch = conv2d_bn(x, 48, (1, 1),  padding='same', strides=(1, 1))
    second_branch = conv2d_bn(second_branch, 64, (5, 5),  padding='same', strides=(1, 1))

    third_branch = conv2d_bn(x, 64, (1, 1),  padding='same', strides=(1,1))
    third_branch = conv2d_bn(third_branch, 96, (3, 3),  padding='same', strides=(1, 1))
    third_branch = conv2d_bn(third_branch, 96, (3, 3),  padding='same', strides=(1, 1))

    fourth_branch = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    fourth_branch = conv2d_bn(fourth_branch, 32, (1, 1),  padding='same', strides=(1, 1))

    x = concatenate([first_branch, second_branch, third_branch, fourth_branch], axis=3)
    return x

# %%
def reduction_block_a(x):
    first_branch = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)

    second_branch = conv2d_bn(x, 384, (3, 3), padding='valid', strides=(2, 2))

    third_branch = conv2d_bn(x, 64, (1, 1), padding='same', strides=(1, 1))
    third_branch = conv2d_bn(third_branch, 96, (3, 3), padding='same', strides=(1, 1))
    third_branch = conv2d_bn(third_branch, 96, (3, 3), padding='valid', strides=(2, 2))

    x = concatenate([first_branch, second_branch, third_branch], axis=3)
    return x

# %%
def inc_block_b(x):
    first_branch = conv2d_bn(x, 192, (1, 1),  padding='same', strides=(1, 1))

    second_branch = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(x)
    second_branch = conv2d_bn(second_branch, 192, (1, 1),  padding='same', strides=(1, 1))

    third_branch = conv2d_bn(x, 128, (1, 1),  padding='same', strides=(1,1))
    third_branch = conv2d_bn(third_branch, 128, (1, 7),  padding='same', strides=(1, 1))
    third_branch = conv2d_bn(third_branch, 192, (7, 1),  padding='same', strides=(1, 1))

    fourth_branch = conv2d_bn(x, 128, (1, 1),  padding='same', strides=(1,1))
    fourth_branch = conv2d_bn(fourth_branch, 128, (7, 1),  padding='same', strides=(1, 1))
    fourth_branch = conv2d_bn(fourth_branch, 128, (1, 7),  padding='same', strides=(1, 1))
    fourth_branch = conv2d_bn(fourth_branch, 128, (7, 1),  padding='same', strides=(1, 1))
    fourth_branch = conv2d_bn(fourth_branch, 192, (1, 7),  padding='same', strides=(1, 1))

    x = concatenate([first_branch, second_branch, third_branch, fourth_branch], axis=3)
    return x

# %%
def reduction_block_b(x):
    first_branch = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)

    second_branch = conv2d_bn(x, 192, (1, 1),  padding='same', strides=(1, 1))
    second_branch = conv2d_bn(second_branch, 320, (3, 3),  padding='valid', strides=(2, 2))

    third_branch = conv2d_bn(x, 192, (1, 1),  padding='same', strides=(1, 1))
    third_branch = conv2d_bn(third_branch, 192, (1, 7),  padding='same', strides=(1, 1))
    third_branch = conv2d_bn(third_branch, 192, (7, 1),  padding='same', strides=(1, 1))
    third_branch = conv2d_bn(third_branch, 192, (3, 3),  padding='valid', strides=(2, 2))

    x = concatenate([first_branch, second_branch, third_branch], axis=3)
    return x

# %%
def inc_block_c(x):
    first_branch = conv2d_bn(x, 320, (1, 1),  padding='same', strides=(1, 1))

    second_branch = conv2d_bn(x, 384, (1, 1),  padding='same', strides=(1, 1))
    second_branch_1 = conv2d_bn(second_branch, 384, (1, 3),  padding='same', strides=(1, 1))
    second_branch_2 = conv2d_bn(second_branch, 384, (3, 1),  padding='same', strides=(1, 1))
    second_branch = concatenate([second_branch_1, second_branch_2], axis=3)

    third_branch = conv2d_bn(x, 448, (1, 1),  padding='same', strides=(1,1))
    third_branch = conv2d_bn(third_branch, 384, (3, 3),  padding='same', strides=(1, 1))
    third_branch_1 = conv2d_bn(third_branch, 384, (1, 3),  padding='same', strides=(1, 1))
    third_branch_2 = conv2d_bn(third_branch, 384, (3, 1),  padding='same', strides=(1, 1))
    third_branch = concatenate([third_branch_1, third_branch_2], axis=3)

    fourth_branch = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    fourth_branch = conv2d_bn(fourth_branch, 192, (1, 1),  padding='same', strides=(1, 1))

    x = concatenate([first_branch, second_branch, third_branch, fourth_branch], axis=3)
    return x

# %%
def Inception_V3():
    input = Input(shape=(299, 299, 3))

    x = conv2d_bn(input, 32, (3, 3),  padding='valid', strides=(2,2))
    x = conv2d_bn(x, 32, (3, 3),  padding='valid', strides=(1,1))
    x = conv2d_bn(x, 64, (3, 3),  padding='same', strides=(1,1))

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)

    x = conv2d_bn(x, 80, (1, 1),  padding='valid', strides=(1,1))
    x = conv2d_bn(x, 192, (3, 3),  padding='valid', strides=(1,1))

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)

    x = inc_block_a(x)
    x = inc_block_a(x)
    x = inc_block_a(x)

    x = reduction_block_a(x)

    x = inc_block_b(x)
    x = inc_block_b(x)
    x = inc_block_b(x)
    x = inc_block_b(x)

    x = reduction_block_b(x)

    x = inc_block_c(x)
    x = inc_block_c(x)

    x = GlobalAveragePooling2D(name='avg_pool')(x)

    x = Dense(2048, activation='relu')(x)

    x = Dense(1000, activation='softmax', name='predictions')(x)

    model = Model(input, x, name='InceptionV3')

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model = Inception_V3()

# %%
model.summary()
# Out:
# Model: "InceptionV3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_18            │ (None, 299, 299, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1344 (Conv2D)      │ (None, 149, 149, 32)   │            896 │ input_layer_18[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1344  │ (None, 149, 149, 32)   │             96 │ conv2d_1344[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1344 (ReLU)         │ (None, 149, 149, 32)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1345 (Conv2D)      │ (None, 147, 147, 32)   │          9,248 │ re_lu_1344[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1345  │ (None, 147, 147, 32)   │             96 │ conv2d_1345[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1345 (ReLU)         │ (None, 147, 147, 32)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1346 (Conv2D)      │ (None, 147, 147, 64)   │         18,496 │ re_lu_1345[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1346  │ (None, 147, 147, 64)   │            192 │ conv2d_1346[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1346 (ReLU)         │ (None, 147, 147, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_122         │ (None, 73, 73, 64)     │              0 │ re_lu_1346[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1347 (Conv2D)      │ (None, 73, 73, 80)     │          5,200 │ max_pooling2d_122[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1347  │ (None, 73, 73, 80)     │            240 │ conv2d_1347[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1347 (ReLU)         │ (None, 73, 73, 80)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1348 (Conv2D)      │ (None, 71, 71, 192)    │        138,432 │ re_lu_1347[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1348  │ (None, 71, 71, 192)    │            576 │ conv2d_1348[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1348 (ReLU)         │ (None, 71, 71, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_123         │ (None, 35, 35, 192)    │              0 │ re_lu_1348[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1352 (Conv2D)      │ (None, 35, 35, 64)     │         12,352 │ max_pooling2d_123[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1352  │ (None, 35, 35, 64)     │            192 │ conv2d_1352[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1352 (ReLU)         │ (None, 35, 35, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1350 (Conv2D)      │ (None, 35, 35, 48)     │          9,264 │ max_pooling2d_123[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1353 (Conv2D)      │ (None, 35, 35, 96)     │         55,392 │ re_lu_1352[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1350  │ (None, 35, 35, 48)     │            144 │ conv2d_1350[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1353  │ (None, 35, 35, 96)     │            288 │ conv2d_1353[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1350 (ReLU)         │ (None, 35, 35, 48)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1353 (ReLU)         │ (None, 35, 35, 96)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_124         │ (None, 35, 35, 192)    │              0 │ max_pooling2d_123[0][… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1349 (Conv2D)      │ (None, 35, 35, 64)     │         12,352 │ max_pooling2d_123[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1351 (Conv2D)      │ (None, 35, 35, 64)     │         76,864 │ re_lu_1350[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1354 (Conv2D)      │ (None, 35, 35, 96)     │         83,040 │ re_lu_1353[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1355 (Conv2D)      │ (None, 35, 35, 32)     │          6,176 │ max_pooling2d_124[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1349  │ (None, 35, 35, 64)     │            192 │ conv2d_1349[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1351  │ (None, 35, 35, 64)     │            192 │ conv2d_1351[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1354  │ (None, 35, 35, 96)     │            288 │ conv2d_1354[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1355  │ (None, 35, 35, 32)     │             96 │ conv2d_1355[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1349 (ReLU)         │ (None, 35, 35, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1351 (ReLU)         │ (None, 35, 35, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1354 (ReLU)         │ (None, 35, 35, 96)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1355 (ReLU)         │ (None, 35, 35, 32)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_182           │ (None, 35, 35, 256)    │              0 │ re_lu_1349[0][0],      │
# │ (Concatenate)             │                        │                │ re_lu_1351[0][0],      │
# │                           │                        │                │ re_lu_1354[0][0],      │
# │                           │                        │                │ re_lu_1355[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1359 (Conv2D)      │ (None, 35, 35, 64)     │         16,448 │ concatenate_182[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1359  │ (None, 35, 35, 64)     │            192 │ conv2d_1359[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1359 (ReLU)         │ (None, 35, 35, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1357 (Conv2D)      │ (None, 35, 35, 48)     │         12,336 │ concatenate_182[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1360 (Conv2D)      │ (None, 35, 35, 96)     │         55,392 │ re_lu_1359[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1357  │ (None, 35, 35, 48)     │            144 │ conv2d_1357[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1360  │ (None, 35, 35, 96)     │            288 │ conv2d_1360[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1357 (ReLU)         │ (None, 35, 35, 48)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1360 (ReLU)         │ (None, 35, 35, 96)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_125         │ (None, 35, 35, 256)    │              0 │ concatenate_182[0][0]  │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1356 (Conv2D)      │ (None, 35, 35, 64)     │         16,448 │ concatenate_182[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1358 (Conv2D)      │ (None, 35, 35, 64)     │         76,864 │ re_lu_1357[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1361 (Conv2D)      │ (None, 35, 35, 96)     │         83,040 │ re_lu_1360[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1362 (Conv2D)      │ (None, 35, 35, 32)     │          8,224 │ max_pooling2d_125[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1356  │ (None, 35, 35, 64)     │            192 │ conv2d_1356[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1358  │ (None, 35, 35, 64)     │            192 │ conv2d_1358[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1361  │ (None, 35, 35, 96)     │            288 │ conv2d_1361[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1362  │ (None, 35, 35, 32)     │             96 │ conv2d_1362[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1356 (ReLU)         │ (None, 35, 35, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1358 (ReLU)         │ (None, 35, 35, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1361 (ReLU)         │ (None, 35, 35, 96)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1362 (ReLU)         │ (None, 35, 35, 32)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_183           │ (None, 35, 35, 256)    │              0 │ re_lu_1356[0][0],      │
# │ (Concatenate)             │                        │                │ re_lu_1358[0][0],      │
# │                           │                        │                │ re_lu_1361[0][0],      │
# │                           │                        │                │ re_lu_1362[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1366 (Conv2D)      │ (None, 35, 35, 64)     │         16,448 │ concatenate_183[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1366  │ (None, 35, 35, 64)     │            192 │ conv2d_1366[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1366 (ReLU)         │ (None, 35, 35, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1364 (Conv2D)      │ (None, 35, 35, 48)     │         12,336 │ concatenate_183[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1367 (Conv2D)      │ (None, 35, 35, 96)     │         55,392 │ re_lu_1366[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1364  │ (None, 35, 35, 48)     │            144 │ conv2d_1364[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1367  │ (None, 35, 35, 96)     │            288 │ conv2d_1367[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1364 (ReLU)         │ (None, 35, 35, 48)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1367 (ReLU)         │ (None, 35, 35, 96)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_126         │ (None, 35, 35, 256)    │              0 │ concatenate_183[0][0]  │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1363 (Conv2D)      │ (None, 35, 35, 64)     │         16,448 │ concatenate_183[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1365 (Conv2D)      │ (None, 35, 35, 64)     │         76,864 │ re_lu_1364[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1368 (Conv2D)      │ (None, 35, 35, 96)     │         83,040 │ re_lu_1367[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1369 (Conv2D)      │ (None, 35, 35, 32)     │          8,224 │ max_pooling2d_126[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1363  │ (None, 35, 35, 64)     │            192 │ conv2d_1363[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1365  │ (None, 35, 35, 64)     │            192 │ conv2d_1365[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1368  │ (None, 35, 35, 96)     │            288 │ conv2d_1368[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1369  │ (None, 35, 35, 32)     │             96 │ conv2d_1369[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1363 (ReLU)         │ (None, 35, 35, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1365 (ReLU)         │ (None, 35, 35, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1368 (ReLU)         │ (None, 35, 35, 96)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1369 (ReLU)         │ (None, 35, 35, 32)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_184           │ (None, 35, 35, 256)    │              0 │ re_lu_1363[0][0],      │
# │ (Concatenate)             │                        │                │ re_lu_1365[0][0],      │
# │                           │                        │                │ re_lu_1368[0][0],      │
# │                           │                        │                │ re_lu_1369[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1371 (Conv2D)      │ (None, 35, 35, 64)     │         16,448 │ concatenate_184[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1371  │ (None, 35, 35, 64)     │            192 │ conv2d_1371[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1371 (ReLU)         │ (None, 35, 35, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1372 (Conv2D)      │ (None, 35, 35, 96)     │         55,392 │ re_lu_1371[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1372  │ (None, 35, 35, 96)     │            288 │ conv2d_1372[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1372 (ReLU)         │ (None, 35, 35, 96)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1370 (Conv2D)      │ (None, 17, 17, 384)    │        885,120 │ concatenate_184[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1373 (Conv2D)      │ (None, 17, 17, 96)     │         83,040 │ re_lu_1372[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1370  │ (None, 17, 17, 384)    │          1,152 │ conv2d_1370[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1373  │ (None, 17, 17, 96)     │            288 │ conv2d_1373[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_127         │ (None, 17, 17, 256)    │              0 │ concatenate_184[0][0]  │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1370 (ReLU)         │ (None, 17, 17, 384)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1373 (ReLU)         │ (None, 17, 17, 96)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_185           │ (None, 17, 17, 736)    │              0 │ max_pooling2d_127[0][… │
# │ (Concatenate)             │                        │                │ re_lu_1370[0][0],      │
# │                           │                        │                │ re_lu_1373[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1379 (Conv2D)      │ (None, 17, 17, 128)    │         94,336 │ concatenate_185[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1379  │ (None, 17, 17, 128)    │            384 │ conv2d_1379[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1379 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1380 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1379[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1380  │ (None, 17, 17, 128)    │            384 │ conv2d_1380[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1380 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1376 (Conv2D)      │ (None, 17, 17, 128)    │         94,336 │ concatenate_185[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1381 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1380[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1376  │ (None, 17, 17, 128)    │            384 │ conv2d_1376[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1381  │ (None, 17, 17, 128)    │            384 │ conv2d_1381[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1376 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1381 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1377 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1376[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1382 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1381[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1377  │ (None, 17, 17, 128)    │            384 │ conv2d_1377[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1382  │ (None, 17, 17, 128)    │            384 │ conv2d_1382[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_68      │ (None, 17, 17, 736)    │              0 │ concatenate_185[0][0]  │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1377 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1382 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1374 (Conv2D)      │ (None, 17, 17, 192)    │        141,504 │ concatenate_185[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1375 (Conv2D)      │ (None, 17, 17, 192)    │        141,504 │ average_pooling2d_68[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1378 (Conv2D)      │ (None, 17, 17, 192)    │        172,224 │ re_lu_1377[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1383 (Conv2D)      │ (None, 17, 17, 192)    │        172,224 │ re_lu_1382[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1374  │ (None, 17, 17, 192)    │            576 │ conv2d_1374[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1375  │ (None, 17, 17, 192)    │            576 │ conv2d_1375[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1378  │ (None, 17, 17, 192)    │            576 │ conv2d_1378[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1383  │ (None, 17, 17, 192)    │            576 │ conv2d_1383[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1374 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1375 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1378 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1383 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_186           │ (None, 17, 17, 768)    │              0 │ re_lu_1374[0][0],      │
# │ (Concatenate)             │                        │                │ re_lu_1375[0][0],      │
# │                           │                        │                │ re_lu_1378[0][0],      │
# │                           │                        │                │ re_lu_1383[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1389 (Conv2D)      │ (None, 17, 17, 128)    │         98,432 │ concatenate_186[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1389  │ (None, 17, 17, 128)    │            384 │ conv2d_1389[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1389 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1390 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1389[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1390  │ (None, 17, 17, 128)    │            384 │ conv2d_1390[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1390 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1386 (Conv2D)      │ (None, 17, 17, 128)    │         98,432 │ concatenate_186[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1391 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1390[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1386  │ (None, 17, 17, 128)    │            384 │ conv2d_1386[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1391  │ (None, 17, 17, 128)    │            384 │ conv2d_1391[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1386 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1391 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1387 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1386[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1392 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1391[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1387  │ (None, 17, 17, 128)    │            384 │ conv2d_1387[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1392  │ (None, 17, 17, 128)    │            384 │ conv2d_1392[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_69      │ (None, 17, 17, 768)    │              0 │ concatenate_186[0][0]  │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1387 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1392 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1384 (Conv2D)      │ (None, 17, 17, 192)    │        147,648 │ concatenate_186[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1385 (Conv2D)      │ (None, 17, 17, 192)    │        147,648 │ average_pooling2d_69[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1388 (Conv2D)      │ (None, 17, 17, 192)    │        172,224 │ re_lu_1387[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1393 (Conv2D)      │ (None, 17, 17, 192)    │        172,224 │ re_lu_1392[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1384  │ (None, 17, 17, 192)    │            576 │ conv2d_1384[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1385  │ (None, 17, 17, 192)    │            576 │ conv2d_1385[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1388  │ (None, 17, 17, 192)    │            576 │ conv2d_1388[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1393  │ (None, 17, 17, 192)    │            576 │ conv2d_1393[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1384 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1385 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1388 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1393 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_187           │ (None, 17, 17, 768)    │              0 │ re_lu_1384[0][0],      │
# │ (Concatenate)             │                        │                │ re_lu_1385[0][0],      │
# │                           │                        │                │ re_lu_1388[0][0],      │
# │                           │                        │                │ re_lu_1393[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1399 (Conv2D)      │ (None, 17, 17, 128)    │         98,432 │ concatenate_187[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1399  │ (None, 17, 17, 128)    │            384 │ conv2d_1399[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1399 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1400 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1399[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1400  │ (None, 17, 17, 128)    │            384 │ conv2d_1400[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1400 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1396 (Conv2D)      │ (None, 17, 17, 128)    │         98,432 │ concatenate_187[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1401 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1400[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1396  │ (None, 17, 17, 128)    │            384 │ conv2d_1396[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1401  │ (None, 17, 17, 128)    │            384 │ conv2d_1401[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1396 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1401 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1397 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1396[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1402 (Conv2D)      │ (None, 17, 17, 128)    │        114,816 │ re_lu_1401[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1397  │ (None, 17, 17, 128)    │            384 │ conv2d_1397[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1402  │ (None, 17, 17, 128)    │            384 │ conv2d_1402[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_70      │ (None, 17, 17, 768)    │              0 │ concatenate_187[0][0]  │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1397 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1402 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1394 (Conv2D)      │ (None, 17, 17, 192)    │        147,648 │ concatenate_187[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1395 (Conv2D)      │ (None, 17, 17, 192)    │        147,648 │ average_pooling2d_70[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1398 (Conv2D)      │ (None, 17, 17, 192)    │        172,224 │ re_lu_1397[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1403 (Conv2D)      │ (None, 17, 17, 192)    │        172,224 │ re_lu_1402[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1394  │ (None, 17, 17, 192)    │            576 │ conv2d_1394[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1395  │ (None, 17, 17, 192)    │            576 │ conv2d_1395[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1398  │ (None, 17, 17, 192)    │            576 │ conv2d_1398[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1403  │ (None, 17, 17, 192)    │            576 │ conv2d_1403[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1394 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1395 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1398 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1403 (ReLU)         │ (None, 17, 17, 192)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_188           │ (None, 17, 17, 768)    │              0 │ re_lu_1394[0][0],      │
# │ (Concatenate)             │                        │                │ re_lu_1395[0][0],      │
# │                           │                        │                │ re_lu_1398[0][0],      │
# │                           │                        │                │ re_lu_1403[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1409 (Conv2D)      │ (None, 17, 17, 128)    │         98,432 │ concatenate_188[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1409  │ (None, 17, 17, 128)    │            384 │ conv2d_1409[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1409 (ReLU)         │ (None, 17, 17, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │                           │                        │                │ re_lu_1419[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1424 (Conv2D)      │ (None, 8, 8, 448)      │        573,888 │ concatenate_190[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1424  │ (None, 8, 8, 448)      │          1,344 │ conv2d_1424[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1424 (ReLU)         │ (None, 8, 8, 448)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1421 (Conv2D)      │ (None, 8, 8, 384)      │        491,904 │ concatenate_190[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1425 (Conv2D)      │ (None, 8, 8, 384)      │      1,548,672 │ re_lu_1424[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1421  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1421[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1425  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1425[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1421 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1425 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1422 (Conv2D)      │ (None, 8, 8, 384)      │        442,752 │ re_lu_1421[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1423 (Conv2D)      │ (None, 8, 8, 384)      │        442,752 │ re_lu_1421[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1426 (Conv2D)      │ (None, 8, 8, 384)      │        442,752 │ re_lu_1425[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1427 (Conv2D)      │ (None, 8, 8, 384)      │        442,752 │ re_lu_1425[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_129         │ (None, 8, 8, 1280)     │              0 │ concatenate_190[0][0]  │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1420 (Conv2D)      │ (None, 8, 8, 320)      │        409,920 │ concatenate_190[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1422  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1422[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1423  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1423[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1426  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1426[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1427  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1427[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1428 (Conv2D)      │ (None, 8, 8, 192)      │        245,952 │ max_pooling2d_129[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1420  │ (None, 8, 8, 320)      │            960 │ conv2d_1420[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1422 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1423 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1426 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1427 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1428  │ (None, 8, 8, 192)      │            576 │ conv2d_1428[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1420 (ReLU)         │ (None, 8, 8, 320)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_191           │ (None, 8, 8, 768)      │              0 │ re_lu_1422[0][0],      │
# │ (Concatenate)             │                        │                │ re_lu_1423[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_192           │ (None, 8, 8, 768)      │              0 │ re_lu_1426[0][0],      │
# │ (Concatenate)             │                        │                │ re_lu_1427[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1428 (ReLU)         │ (None, 8, 8, 192)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_193           │ (None, 8, 8, 2048)     │              0 │ re_lu_1420[0][0],      │
# │ (Concatenate)             │                        │                │ concatenate_191[0][0], │
# │                           │                        │                │ concatenate_192[0][0], │
# │                           │                        │                │ re_lu_1428[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1433 (Conv2D)      │ (None, 8, 8, 448)      │        917,952 │ concatenate_193[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1433  │ (None, 8, 8, 448)      │          1,344 │ conv2d_1433[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1433 (ReLU)         │ (None, 8, 8, 448)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1430 (Conv2D)      │ (None, 8, 8, 384)      │        786,816 │ concatenate_193[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1434 (Conv2D)      │ (None, 8, 8, 384)      │      1,548,672 │ re_lu_1433[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1430  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1430[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1434  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1434[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1430 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1434 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1431 (Conv2D)      │ (None, 8, 8, 384)      │        442,752 │ re_lu_1430[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1432 (Conv2D)      │ (None, 8, 8, 384)      │        442,752 │ re_lu_1430[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1435 (Conv2D)      │ (None, 8, 8, 384)      │        442,752 │ re_lu_1434[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1436 (Conv2D)      │ (None, 8, 8, 384)      │        442,752 │ re_lu_1434[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_130         │ (None, 8, 8, 2048)     │              0 │ concatenate_193[0][0]  │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1429 (Conv2D)      │ (None, 8, 8, 320)      │        655,680 │ concatenate_193[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1431  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1431[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1432  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1432[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1435  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1435[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1436  │ (None, 8, 8, 384)      │          1,152 │ conv2d_1436[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1437 (Conv2D)      │ (None, 8, 8, 192)      │        393,408 │ max_pooling2d_130[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1429  │ (None, 8, 8, 320)      │            960 │ conv2d_1429[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1431 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1432 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1435 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1436 (ReLU)         │ (None, 8, 8, 384)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1437  │ (None, 8, 8, 192)      │            576 │ conv2d_1437[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1429 (ReLU)         │ (None, 8, 8, 320)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_194           │ (None, 8, 8, 768)      │              0 │ re_lu_1431[0][0],      │
# │ (Concatenate)             │                        │                │ re_lu_1432[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_195           │ (None, 8, 8, 768)      │              0 │ re_lu_1435[0][0],      │
# │ (Concatenate)             │                        │                │ re_lu_1436[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1437 (ReLU)         │ (None, 8, 8, 192)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_196           │ (None, 8, 8, 2048)     │              0 │ re_lu_1429[0][0],      │
# │ (Concatenate)             │                        │                │ concatenate_194[0][0], │
# │                           │                        │                │ concatenate_195[0][0], │
# │                           │                        │                │ re_lu_1437[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ avg_pool                  │ (None, 2048)           │              0 │ concatenate_196[0][0]  │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 2048)           │      4,196,352 │ avg_pool[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ predictions (Dense)       │ (None, 1000)           │      2,049,000 │ dense_7[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 26,274,632 (100.23 MB)
#  Trainable params: 26,241,864 (100.10 MB)
#  Non-trainable params: 32,768 (128.00 KB)
